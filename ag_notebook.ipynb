# %% [markdown]
# ### Task 1

# %%
import pandas as pd

# %%
ag_df = pd.read_csv('2011_ag.csv')

# %%
print(ag_df.head())
# Out:
#   code       state category  total exports   beef  pork  poultry   dairy  \
# 0   AL     Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK      Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ     Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR    Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA  California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton
# 0          14.33  34.9   70.0   317.61
# 1           1.56   0.0    0.0     0.00
# 2         386.91   7.3   48.7   423.95
# 3          11.45  69.5  114.5   665.44
# 4        2106.79  34.6  249.3  1064.95

# %%
print(ag_df.shape)
# Out:
# (50, 17)

# %% [markdown]
# Task 1 questions:
# 1. 50 rows
# 2. 17 columns
# 3. each state

# %% [markdown]
# ### Task 2 - Explore Column Names

# %%
print(ag_df.columns)
print(len(ag_df.columns))
print(ag_df['total exports'])
# Out:
# Index(['code', 'state', 'category', 'total exports', 'beef', 'pork', 'poultry',
#        'dairy', 'fruits fresh', 'fruits proc', 'total fruits', 'veggies fresh',
#        'veggies proc', 'total veggies', 'corn', 'wheat', 'cotton'],
#       dtype='object')
# 17
# 0      1390.63
# 1        13.31
# 2      1463.17
# 3      3586.02
# 4     16472.88
# 5      1851.33
# 6       259.62
# 7       282.19
# 8      3764.09
# 9      2860.84
# 10      401.84
# 11     2078.89
# 12     8709.48
# 13     5050.23
# 14    11273.76
# 15     4589.01
# 16     1889.15
# 17     1914.23
# 18      278.37
# 19      692.75
# 20      248.65
# 21     3164.16
# 22     7192.33
# 23     2170.80
# 24     3933.42
# 25     1718.00
# 26     7114.13
# 27      139.89
# 28       73.06
# 29      500.40
# 30      751.58
# 31     1488.90
# 32     3806.05
# 33     3761.96
# 34     3979.79
# 35     1646.41
# 36     1794.57
# 37     1969.87
# 38       31.59
# 39      929.93
# 40     3770.19
# 41     1535.13
# 42     6648.22
# 43      453.39
# 44      180.14
# 45     1146.48
# 46     3894.81
# 47      138.89
# 48     3090.23
# 49      349.69
# Name: total exports, dtype: float64

# %% [markdown]
# Task 2 question:
# The `total exports` column is the most useful summary because it is the sum of all of the other columns, giving one number to summarize the whole state's exports.

# %% [markdown]
# ### Task 3 - Select One Column

# %%
state_names = ag_df['state']
print(state_names)
print(state_names.dtype)
print(type(state_names))
# Out:
# 0            Alabama
# 1             Alaska
# 2            Arizona
# 3           Arkansas
# 4         California
# 5           Colorado
# 6        Connecticut
# 7           Delaware
# 8            Florida
# 9            Georgia
# 10            Hawaii
# 11             Idaho
# 12          Illinois
# 13           Indiana
# 14              Iowa
# 15            Kansas
# 16          Kentucky
# 17         Louisiana
# 18             Maine
# 19          Maryland
# 20     Massachusetts
# 21          Michigan
# 22         Minnesota
# 23       Mississippi
# 24          Missouri
# 25           Montana
# 26          Nebraska
# 27            Nevada
# 28     New Hampshire
# 29        New Jersey
# 30        New Mexico
# 31          New York
# 32    North Carolina
# 33      North Dakota
# 34              Ohio
# 35          Oklahoma
# 36            Oregon
# 37      Pennsylvania
# 38      Rhode Island
# 39    South Carolina
# 40      South Dakota
# 41         Tennessee
# 42             Texas
# 43              Utah
# 44           Vermont
# 45          Virginia
# 46        Washington
# 47     West Virginia
# 48         Wisconsin
# 49           Wyoming
# Name: state, dtype: object
# object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Task 3 questions:
# 1. the `state` column has dtype object.
# 2. Series is one column, or a list with a title. A DataFrame is a group of series built into a dataset.s

# %% [markdown]
# ### Task 4

# %%
grain = ag_df[['state', 'corn', 'wheat']]
print(grain)
print(type(grain))
print(f'shape: {grain.shape}')
# Out:
#              state    corn   wheat
# 0          Alabama    34.9    70.0
# 1           Alaska     0.0     0.0
# 2          Arizona     7.3    48.7
# 3         Arkansas    69.5   114.5
# 4       California    34.6   249.3
# 5         Colorado   183.2   400.5
# 6      Connecticut     0.0     0.0
# 7         Delaware    26.9    22.9
# 8          Florida     3.5     1.8
# 9          Georgia    57.8    65.4
# 10          Hawaii     0.0     0.0
# 11           Idaho    24.0   568.2
# 12        Illinois  2228.5   223.8
# 13         Indiana  1123.2   114.0
# 14            Iowa  2529.8     3.1
# 15          Kansas   457.3  1426.5
# 16        Kentucky   179.1   149.3
# 17       Louisiana    91.4    78.7
# 18           Maine     0.0     0.0
# 19        Maryland    54.1    55.8
# 20   Massachusetts     0.0     0.0
# 21        Michigan   381.5   247.0
# 22       Minnesota  1264.3   538.1
# 23     Mississippi   110.0   102.2
# 24        Missouri   428.8   161.7
# 25         Montana     5.4  1198.1
# 26        Nebraska  1735.9   292.3
# 27          Nevada     0.0     5.4
# 28   New Hampshire     0.0     0.0
# 29      New Jersey    10.1     6.7
# 30      New Mexico    11.2    13.9
# 31        New York   106.1    29.9
# 32  North Carolina    92.2   200.3
# 33    North Dakota   236.1  1664.5
# 34            Ohio   535.1   207.4
# 35        Oklahoma    27.5   324.8
# 36          Oregon    11.7   320.3
# 37    Pennsylvania   112.1    41.0
# 38    Rhode Island     0.0     0.0
# 39  South Carolina    32.1    55.3
# 40    South Dakota   643.6   704.5
# 41       Tennessee    88.8   100.0
# 42           Texas   167.2   309.7
# 43            Utah     5.3    42.8
# 44         Vermont     0.0     0.0
# 45        Virginia    39.5    77.5
# 46      Washington    29.5   786.3
# 47   West Virginia     3.5     1.6
# 48       Wisconsin   460.5    96.7
# 49         Wyoming     9.0    20.7
# <class 'pandas.core.frame.DataFrame'>
# shape: (50, 3)

# %% [markdown]
# selecting two or more creates a DataFrame because a Series is only one column whereas a DataFrame is multiple Series put together.

# %% [markdown]
# ### Task 5

# %%
print(ag_df.index)
print(ag_df.loc[0])
print(ag_df.loc[4])
print(type(ag_df.loc[0]))
# Out:
# RangeIndex(start=0, stop=50, step=1)
# code                  AL
# state            Alabama
# category           state
# total exports    1390.63
# beef                34.4
# pork                10.6
# poultry            481.0
# dairy               4.06
# fruits fresh         8.0
# fruits proc         17.1
# total fruits       25.11
# veggies fresh        5.5
# veggies proc         8.9
# total veggies      14.33
# corn                34.9
# wheat               70.0
# cotton            317.61
# Name: 0, dtype: object
# code                     CA
# state            California
# category              state
# total exports      16472.88
# beef                  228.7
# pork                   11.1
# poultry               225.4
# dairy                929.95
# fruits fresh         2791.8
# fruits proc          5944.6
# total fruits         8736.4
# veggies fresh         803.2
# veggies proc         1303.5
# total veggies       2106.79
# corn                   34.6
# wheat                 249.3
# cotton              1064.95
# Name: 4, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# The index of the first row is `0`
# The state in row 4 is *California*

# %% [markdown]
# ### Task 6

# %%
first_chunk = ag_df.loc[5:10]
print(first_chunk)
print(first_chunk.shape)
# Out:
#    code        state category  total exports   beef  pork  poultry  dairy  \
# 5    CO     Colorado    state        1851.33  261.4  66.0     14.0  71.94
# 6    CT  Connecticut    state         259.62    1.1   0.1      6.9   9.49
# 7    DE     Delaware    state         282.19    0.4   0.6    114.7   2.30
# 8    FL      Florida    state        3764.09   42.6   0.9     56.9  66.31
# 9    GA      Georgia    state        2860.84   31.0  18.9    630.4  38.38
# 10   HI       Hawaii    state         401.84    4.0   0.7      1.3   1.16
#
#     fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 5            5.7         12.2         17.99           45.1          73.2
# 6            4.2          8.9         13.10            4.3           6.9
# 7            0.5          1.0          1.53            7.6          12.4
# 8          438.2        933.1       1371.36          171.9         279.0
# 9           74.6        158.9        233.51           59.0          95.8
# 10          17.7         37.8         55.51            9.5          15.4
#
#     total veggies   corn  wheat   cotton
# 5          118.27  183.2  400.5     0.00
# 6           11.16    0.0    0.0     0.00
# 7           20.03   26.9   22.9     0.00
# 8          450.86    3.5    1.8    78.24
# 9          154.77   57.8   65.4  1154.07
# 10          24.83    0.0    0.0     0.00
# (6, 17)

# %% [markdown]
# Task 6 Questions
# Rows returned: 6
# Yes our row count matches the rule

# %% [markdown]
# ## Task 7

# %%
spot_check = ag_df.loc[[0, 9, 24]]
print(spot_check)
print(spot_check["state"])
# Out:
#    code     state category  total exports   beef   pork  poultry  dairy  \
# 0    AL   Alabama    state        1390.63   34.4   10.6    481.0   4.06
# 9    GA   Georgia    state        2860.84   31.0   18.9    630.4  38.38
# 24   MO  Missouri    state        3933.42  137.2  277.3    196.1  34.26
#
#     fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0            8.0         17.1         25.11            5.5           8.9
# 9           74.6        158.9        233.51           59.0          95.8
# 24           4.2          9.0         13.18            6.8          11.1
#
#     total veggies   corn  wheat   cotton
# 0           14.33   34.9   70.0   317.61
# 9          154.77   57.8   65.4  1154.07
# 24          17.90  428.8  161.7   345.29
# 0      Alabama
# 9      Georgia
# 24    Missouri
# Name: state, dtype: object

# %% [markdown]
# ##Task 8

# %%
print(ag_df.iloc[0])
print("----------")
print(ag_df.iloc[-1])
print("--------")
first_five = ag_df.iloc[0:5]
print(first_five)
# Out:
# code                  AL
# state            Alabama
# category           state
# total exports    1390.63
# beef                34.4
# pork                10.6
# poultry            481.0
# dairy               4.06
# fruits fresh         8.0
# fruits proc         17.1
# total fruits       25.11
# veggies fresh        5.5
# veggies proc         8.9
# total veggies      14.33
# corn                34.9
# wheat               70.0
# cotton            317.61
# Name: 0, dtype: object
# ----------
# code                  WY
# state            Wyoming
# category           state
# total exports     349.69
# beef                75.1
# pork                33.2
# poultry              0.1
# dairy               2.89
# fruits fresh         0.1
# fruits proc          0.1
# total fruits        0.17
# veggies fresh        3.9
# veggies proc         6.3
# total veggies      10.23
# corn                 9.0
# wheat               20.7
# cotton               0.0
# Name: 49, dtype: object
# --------
#   code       state category  total exports   beef  pork  poultry   dairy  \
# 0   AL     Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK      Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ     Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR    Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA  California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton
# 0          14.33  34.9   70.0   317.61
# 1           1.56   0.0    0.0     0.00
# 2         386.91   7.3   48.7   423.95
# 3          11.45  69.5  114.5   665.44
# 4        2106.79  34.6  249.3  1064.95

# %% [markdown]
# We printed five rows. We did not get six because it is exclusive on the stop value)

# %% [markdown]
# ##Task 9

# %%
top10 = ag_df.loc[10:19]

# %%
print(top10)
# Out:
#    code      state category  total exports   beef    pork  poultry   dairy  \
# 10   HI     Hawaii    state         401.84    4.0     0.7      1.3    1.16
# 11   ID      Idaho    state        2078.89  119.8     0.0      2.4  294.60
# 12   IL   Illinois    state        8709.48   53.7   394.0     14.0   45.82
# 13   IN    Indiana    state        5050.23   21.9   341.9    165.6   89.70
# 14   IA       Iowa    state       11273.76  289.8  1895.6    155.6  107.00
# 15   KS     Kansas    state        4589.01  659.3   179.4      6.4   65.45
# 16   KY   Kentucky    state        1889.15   54.8    34.2    151.3   28.27
# 17   LA  Louisiana    state        1914.23   19.8     0.8     77.2    6.02
# 18   ME      Maine    state         278.37    1.4     0.5     10.4   16.18
# 19   MD   Maryland    state         692.75    5.6     3.1    127.0   24.81
#
#     fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 10          17.7         37.8         55.51            9.5          15.4
# 11           6.9         14.7         21.64          121.7         197.5
# 12           4.0          8.5         12.53           15.2          24.7
# 13           4.1          8.8         12.98           14.4          23.4
# 14           1.0          2.2          3.24            2.7           4.4
# 15           1.0          2.1          3.11            3.6           5.8
# 16           2.1          4.5          6.60            0.0           0.0
# 17           5.7         12.1         17.83            6.6          10.7
# 18          16.6         35.4         52.01           24.0          38.9
# 19           4.1          8.8         12.90            7.8          12.6
#
#     total veggies    corn   wheat  cotton
# 10          24.83     0.0     0.0    0.00
# 11         319.19    24.0   568.2    0.00
# 12          39.95  2228.5   223.8    0.00
# 13          37.89  1123.2   114.0    0.00
# 14           7.10  2529.8     3.1    0.00
# 15           9.32   457.3  1426.5   43.98
# 16           0.00   179.1   149.3    0.00
# 17          17.25    91.4    78.7  280.42
# 18          62.90     0.0     0.0    0.00
# 19          20.43    54.1    55.8    0.00

# %%
top10.loc[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\patri\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 top10.loc[0]
#
# File c:\Users\patri\anaconda3\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\patri\anaconda3\Lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File c:\Users\patri\anaconda3\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
#    1381     # GH#5567 this will fail if the label is not present in the axis.
# -> 1382     return self.obj.xs(label, axis=axis)
#
# File c:\Users\patri\anaconda3\Lib\site-packages\pandas\core\generic.py:4323, in NDFrame.xs(self, key, axis, level, drop_level)
#    4321             new_index = index[loc]
#    4322 else:
# -> 4323     loc = index.get_loc(key)
#    4325     if isinstance(loc, np.ndarray):
#    4326         if loc.dtype == np.bool_:
#
# File c:\Users\patri\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 0

# %%
top10.iloc[0]
# Out:
# code                 HI
# state            Hawaii
# category          state
# total exports    401.84
# beef                4.0
# pork                0.7
# poultry             1.3
# dairy              1.16
# fruits fresh       17.7
# fruits proc        37.8
# total fruits      55.51
# veggies fresh       9.5
# veggies proc       15.4
# total veggies     24.83
# corn                0.0
# wheat               0.0
# cotton              0.0
# Name: 10, dtype: object

# %% [markdown]
# They did not return the same row. iloc grabs the first row by position
# loc uses the label 0. There is no label 0 and because we used top 10, there is no label 0 in the new list

# %% [markdown]
# ##Task 10

# %%
export_preview = ag_df.loc[0:4, ['state', 'total exports']]
print(export_preview)
# Out:
#         state  total exports
# 0     Alabama        1390.63
# 1      Alaska          13.31
# 2     Arizona        1463.17
# 3    Arkansas        3586.02
# 4  California       16472.88

# %%
export_preview = ag_df.loc[20:25, 'beef':'poultry']
print(export_preview)
# Out:
#      beef   pork  poultry
# 20    0.6    0.5      0.6
# 21   37.7  118.1     32.6
# 22  112.3  740.4    189.2
# 23   12.8   30.4    370.8
# 24  137.2  277.3    196.1
# 25  105.0   16.7      1.7

# %% [markdown]
# ##Task 11

# %%
export_preview = ag_df.iloc[:5, :3]
print(export_preview)
# Out:
#   code       state category
# 0   AL     Alabama    state
# 1   AK      Alaska    state
# 2   AZ     Arizona    state
# 3   AR    Arkansas    state
# 4   CA  California    state

# %%
export_preview = ag_df.iloc[10:15, 3:7]
print(export_preview)
# Out:
#     total exports   beef    pork  poultry
# 10         401.84    4.0     0.7      1.3
# 11        2078.89  119.8     0.0      2.4
# 12        8709.48   53.7   394.0     14.0
# 13        5050.23   21.9   341.9    165.6
# 14       11273.76  289.8  1895.6    155.6

# %% [markdown]
# ##Task 12

# %%
focused = ag_df.loc[3:9, ['state', 'total exports', 'beef', 'dairy', 'cotton']]
print(focused)
# Out:
#          state  total exports   beef   dairy   cotton
# 3     Arkansas        3586.02   53.2    3.53   665.44
# 4   California       16472.88  228.7  929.95  1064.95
# 5     Colorado        1851.33  261.4   71.94     0.00
# 6  Connecticut         259.62    1.1    9.49     0.00
# 7     Delaware         282.19    0.4    2.30     0.00
# 8      Florida        3764.09   42.6   66.31    78.24
# 9      Georgia        2860.84   31.0   38.38  1154.07

# %%
print(focused.shape) #confirm you have 10 rows and 5 columns, we have 7  because we changed the number in the range
# Out:
# (7, 5)

# %%
focused_reset = focused.reset_index(drop=True)
print(focused_reset)
# Out:
#          state  total exports   beef   dairy   cotton
# 0     Arkansas        3586.02   53.2    3.53   665.44
# 1   California       16472.88  228.7  929.95  1064.95
# 2     Colorado        1851.33  261.4   71.94     0.00
# 3  Connecticut         259.62    1.1    9.49     0.00
# 4     Delaware         282.19    0.4    2.30     0.00
# 5      Florida        3764.09   42.6   66.31    78.24
# 6      Georgia        2860.84   31.0   38.38  1154.07

# %% [markdown]
# ##Task 13
